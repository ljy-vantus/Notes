# %% [markdown]
# # 마크다운 문법(Syntax)

# %% [markdown]
# ## 제목(Header)

# %% [markdown]
# # 제목 1

# %% [markdown]
# ## 제목 2

# %% [markdown]
# ### 제목 3

# %% [markdown]
# #### 제목 4

# %% [markdown]
# ##### 제목 5

# %% [markdown]
# ###### 제목 6

# %% [markdown]
# * 제목1(h1)과 제목2(h2)는 다음과 같이 표현할 수 있습니다.

# %% [markdown]
# 제목 1
# =====

# %% [markdown]
# 제목 2
# -----

# %% [markdown]
# ## 강조(Emphasis)

# %% [markdown]
# 이텔리체는 *별표(asterisks)* 혹은 _언더바(underscore)_ 를 사용하세요.
# 두껍게는 **별표(asterisk)** 혹은 __언더바(underscore)__ 를 사용하세요.
# **_이텔리체_ 와 두껍게**를 같이 사용할 수 있습니다.
# 취소선은 ~~물결표시(tilde)~~를 사용하세요.
# <u>밑줄</u>은 `<u></u>`를 사용하세요

# %% [markdown]
# ## 목록(List)

# %% [markdown]
# 1. 순서가 필요한 목록
# 1. 순서가 필요한 목록
#     - 순서가 필요하지 않은 목록(서브
#     - 순서가 필요하지 않은 목록(서브)
# 1. 순서가 필요한 목록
#     1. 순서가 필요한 목록(서브)
#     2. 순서가 필요한 목록(서브)
# 1. 순서가 필요한 목록
#
# - 순서가 필요하지 않은 목록에 사용 가능한 기호
#     - 대쉬(hyphen)
#     * 별표(asterisk)
#     + 더하기(plus sign)

# %% [markdown]
# ## 링크(Links)

# %% [markdown]
# [GOOGLE](https://google.com)
# [NAVER](https://naver.com "링크 설며(title)을 작성하세요.")

# %% [markdown]
# ![image.png](attachment:6e2f0d78-c60f-47d7-87ac-106f7a101e37.png)

# %% [markdown]
# ## 특징
#
# 1. 코드를 Cell 단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나  표 등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장

# %% [markdown]
# ## 사전 학습 자료
#
# 다음 링크에서 파이썬 기본편에 대한 학습을 하실 수 있습니다.
# [나도코딩 블로그](https://nadocoding.tistory.com)

# %% [markdown]
# ---
# ## 시각화 예제1: 그래프
#
# - matplotlib을 이용하면 다양한 그래프를 그릴 수 있으며 수행 결과를 바로 확인할 수 있습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## 시각화 예제2: 테이블
#
# - pandas는 복잡한 데이터를 분설할 때 아주 유용합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  0.692780  4.567293
# 2021-01-02  0.543045  0.809765
# 2021-01-03  1.200902  1.401428
# 2021-01-04  0.116954  4.599390
# 2021-01-05  4.066997  4.129563
# 2021-01-06  1.150211  4.608764
# 2021-01-07  1.966491  1.905207
# 2021-01-08  1.238428  3.817145
# 2021-01-09  4.638013  0.052540
# 2021-01-10  1.706770  2.195927

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_e6f25_row0_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e6f25_row0_col1, #T_e6f25_row2_col1 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_e6f25_row1_col0 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_e6f25_row1_col1 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_e6f25_row2_col0 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_e6f25_row3_col0 {
#   background-color: #caeab4;
#   color: #000000;
# }
# #T_e6f25_row3_col1 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_e6f25_row4_col0 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_e6f25_row4_col1 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e6f25">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6f25_level0_col0" class="col_heading level0 col0" >Tokyo</th>
# ...
